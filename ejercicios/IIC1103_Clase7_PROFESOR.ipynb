# %% [markdown]
# <a href="https://colab.research.google.com/github/davidlealo/IIC1103-2026-2-6/blob/main/ejercicios/IIC1103_Clase7_PROFESOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imprimir sin f string

print("Hola Mundo")
# Out:
# Hola Mundo

# %%
# Imprimir sin f string con variable

resultado = "HOY"

print("Hola Mundo", resultado)
# Out:
# Hola Mundo HOY

# %%
# Imprimir sin f string

print("Hola", resultado, "Mundo")
# Out:
# Hola HOY Mundo

# %%
print(f"Hol {resultado} Mundo")
# Out:
# Hol HOY Mundo

# %%
'''

En el DCCasino hay un nuevo tragamonedas (🎰) que te invitan a probar.
Cuentas inicialmente con *3 fichas y nada de dinero*.

Las reglas del tragamonedas son las siguientes:

Por cada tirada, el tragamonedas se consume una ficha.
Si se logra una combinación de tres 7's, ganas $500.
Si se logra una combinación de tres *'s, ganas 3 fichas adicionales.
Ninguna otra combinación te genera ganancias.


'''

# %%
fichas = 3
dinero = 0

# ficha = ficha - 1

# %%
# Por cada tirada (ciclo) debo gastar una ficha
# fichas = fichas - 1
# fichas =- 1

# %%
tirada = ""

# %%
# ***Si*** tengo tres 7's gano 500

if tirada == "777":
  dinero =+ 500

# dinero =+ 500
# dinero = dinero + 500

# %%
# SI la tirada == tres *.s entonces gano 3 fichas

if tirada == "***":
  fichas =+ 3

# %%
fichas
# Out:
# 0

# %%
fichas = 1

# %%
fichas = 3
dinero = 0

while fichas > 0:
  fichas = fichas - 1

  tirada1 = input("Lance el tragamonedas: ")
  tirada2 = input("Lance el tragamonedas: ")
  tirada3 = input("Lance el tragamonedas: ")

  tirada = tirada1 + tirada2 + tirada3
  print(f"tirada actual: {tirada}")

  if tirada == "777":
    dinero = dinero + 500
    print("- Ganaste $500!")
  elif tirada == "***":
    fichas = fichas + 3
    print("- Conseguiste 3 fichas!")

  print(f"- Quedan {fichas} fichas")
# Out:
# Fichas : 2
# Dinero: 0
# Lance el tragamonedas: 7
# Lance el tragamonedas: 7
# Lance el tragamonedas: 7
# tirada actual: 777
# - Ganaste $500!
# - Quedan 2 fichas
# Fichas : 1
# Dinero: 500
# Lance el tragamonedas: *
# Lance el tragamonedas: *
# Lance el tragamonedas: *
# tirada actual: ***
# - Conseguiste 3 fichas!
# - Quedan 4 fichas
# Fichas : 3
# Dinero: 500
# Lance el tragamonedas: 7
# Lance el tragamonedas: 7
# Lance el tragamonedas: 7
# tirada actual: 777
# - Ganaste $500!
# - Quedan 3 fichas
# Fichas : 2
# Dinero: 1000
# Lance el tragamonedas: 4
# Lance el tragamonedas:
# Lance el tragamonedas:
# tirada actual: 4
# - Quedan 2 fichas
# Fichas : 1
# Dinero: 1000
# Lance el tragamonedas: 44
# Lance el tragamonedas: 4
# Lance el tragamonedas: 4
# tirada actual: 4444
# - Quedan 1 fichas
# Fichas : 0
# Dinero: 1000
# Lance el tragamonedas:
# Lance el tragamonedas: 4
# Lance el tragamonedas:
# tirada actual: 4
# - Quedan 0 fichas
