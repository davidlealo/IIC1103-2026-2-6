# %% [markdown]
# <a href="https://colab.research.google.com/github/davidlealo/IIC1103-2026-2-6/blob/main/ejercicios/IIC1103_Clase4_PROFESOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 4 — Control de flujo: alternativas
#
# IIC1103 · Sección 6 · Semestre 2026-2
#
# En esta clase aprenderemos a que un programa tome decisiones. Trabajaremos con cuatro estructuras:
#
# - **FLU-01** · `if` – `else`
# - **FLU-02** · `if` – `elif` – `else`
# - **FLU-03** · `if` sin `else`
# - **FLU-04** · `if` anidados
#
# Cada sección tiene una explicación breve, un ejemplo ejecutable y un ejercicio para que resuelvan.

# %% [markdown]
# ## FLU-01 · `if` – `else`
#
# Sirve para decidir entre dos caminos posibles. Si la condición es `True` se ejecuta el primer bloque; si es `False`, el segundo.
#
# ```
# if condicion:
#     # bloque 1
# else:
#     # bloque 2
# ```
#
# Los dos puntos y la indentación son parte del lenguaje. Un solo espacio de más o de menos rompe el programa.

# %%
nombre = input("Escribe tu nombre: ")
if nombre == "Juan":
    print("Hola Juan!")

if nombre != "Juan":
    print("Hola, ¿cómo te llamas?")
# Out:
# Escribe tu nombre: David
# Hola, ¿cómo te llamas?

# %%
# Ejemplo: par o impar
numero = int(input("Ingresa un número entero: "))

if numero % 2 == 0:
    print("El número es par")
else:
    print("El número es impar")
# Out:
# Ingresa un número entero: 5
# El número es impar

# %%
# Ejemplo: Multiplicar por dos los números pares y por 3 los impares
numero = int(input("Ingresa un número entero: "))

if numero % 2 == 0:
    print(numero * 2)
else:
    print(numero * 3)
# Out:
# Ingresa un número entero: 4
# 8

# %%
# Ejemplo: Multiplicar por dos los números pares y por 3 los impares si usar print dentro de la estructura de control
numero = int(input("Ingresa un número entero: "))

if numero % 2 == 0:
    total = numero * 2
else:
    total = numero * 3

total
# Out:
# Ingresa un número entero: 4
# 8

# %%
# Ejemplo: Multiplicar por dos los números pares y por 3 los impares si usar print dentro de la estructura de control
numero = int(input("Ingresa un número entero: "))

if numero % 2 == 0:
    numero *= 2
else:
    numero *= 3

numero
# Out:
# Ingresa un número entero: 4
# 8

# %%
# ERROR de identación: Multiplicar por dos los números pares y por 3 los impares si usar print dentro de la estructura de control
numero = int(input("Ingresa un número entero: "))

if numero % 2 == 0:
numero *= 2
else:
numero *= 3

numero
# Out:
#   File "/tmp/ipykernel_1453/3089060666.py", line 5
#     numero *= 2
#     ^
# IndentationError: expected an indented block after 'if' statement on line 4

# %%
# ERROR: Multiplicar por dos los números pares y por 3 los impares si usar print dentro de la estructura de control
numero = int(input("Ingresa un número entero: "))

if numero % 2 == 0:
# Out:
#   File "/tmp/ipykernel_1453/2745930959.py", line 4
#     if numero % 2 == 0:
#                        ^
# SyntaxError: incomplete input

# %% [markdown]
# **Ejercicio 1.** Pide al usuario su edad y responde `"Eres mayor de edad"` si tiene 18 o más años, o `"Eres menor de edad"` en caso contrario.

# %%
# tu código

# %% [markdown]
# ## FLU-02 · `if` – `elif` – `else`
#
# Cuando hay más de dos casos posibles, agregamos uno o más `elif` entre el `if` y el `else`.
#
# ```
# if condicion_1:
#     # bloque 1
# elif condicion_2:
#     # bloque 2
# elif condicion_3:
#     # bloque 3
# else:
#     # bloque por defecto
# ```
#
# Python evalúa las condiciones en orden y ejecuta el primer bloque cuya condición sea `True`. El resto se salta por completo.

# %%
# Ejemplo: clasificación de nota
nota = float(input("Ingresa tu nota: "))

if nota >= 6.0:
    print("Excelente")
elif nota >= 5.0:
    print("Muy bueno")
elif nota >= 4.0:
    print("Aprobado")
else:
    print("Reprobado")
# Out:
# Ingresa tu nota: 4
# Aprobado

# %%
# Ejemplo: clasificación de nota
nota = float(input("Ingresa tu nota: "))

if nota >= 6.0:
    print("Excelente")
elif nota >= 5.0:
    print("Muy bueno")
elif nota >= 4.0:
    print("Aprobado")
elif nota >= 3.85:
    nota = 4.0
    print("Aprobado*")
else:
    print("Reprobado")

# %%
# Ejemplo: clasificación de nota
nota = float(input("Ingresa tu nota: "))

if nota >= 6.0:
    print("Excelente", nota)
elif nota >= 5.0:
    print("Muy bueno", nota)
elif nota >= 4.0:
    print("Aprobado", nota)
elif nota >= 3.85:
    nota = 4.0
    print("Aprobado*", nota)
else:
    print("Reprobado")

# %%
numero = int(input("Ingresa un número entero: "))

if numero % 2 == 0:
    print("El número es par")
elif numero % 3 == 0:
    print("El número es múltiplo de 3")
else:
    print("El número no es par ni múltiplo de 3")
# Out:
# Ingresa un número entero: tres
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1453/3747002153.py in <cell line: 0>()
# ----> 1 numero = int(input("Ingresa un número entero: "))
#       2
#       3 if numero % 2 == 0:
#       4     print("El número es par")
#       5 elif numero % 3 == 0:
#
# ValueError: invalid literal for int() with base 10: 'tres'

# %%
nombre = input("Escribe tu nombre: ")
if nombre == "Juan":
 print("Hola Juan!")
elif nombre == "Pedro":
    print("Hola Pedro!")
else:
    print("Hola, ¿cómo te llamas?")
# Out:
# Escribe tu nombre: juan
# Hola, ¿cómo te llamas?

# %% [markdown]
# **Ejercicio 2.** Pide al usuario un número entre 1 y 7 y muestra el día de la semana correspondiente (1 = lunes, 2 = martes, ..., 7 = domingo). Si el número está fuera del rango, indica `"Número inválido"`.

# %%
# tu código

# %% [markdown]
# ## FLU-03 · `if` sin `else`
#
# No siempre hace falta un `else`. A veces sólo queremos hacer algo si la condición se cumple, y no hacer nada en caso contrario.
#
# ```
# if condicion:
#     # bloque
#
# # el programa continúa aquí en ambos casos
# ```
#
# Un `if` sin `else` es más simple y más legible cuando el caso `False` no requiere ninguna acción.

# %%
# Ejemplo: descuento por edad
edad = int(input("Ingresa tu edad: "))
precio = 5000

if edad >= 65:
    precio = precio * 0.7   # 30% de descuento

print("Total a pagar: $", precio)

# %% [markdown]
# También podemos encadenar varios `if` – `elif` sin un `else` final: si ninguna condición se cumple, el programa simplemente no hace nada.

# %%
# Ejemplo: advertencias de temperatura
temp = float(input("Temperatura: "))

if temp < 0:
    print("Advertencia: congelamiento")
elif temp > 35:
    print("Advertencia: calor extremo")
else:
  print("Temperatura razonable")

print("Fin del programa")
# Out:
# Temperatura: 1
# Temperatura razonable
# Fin del programa

# %% [markdown]
# **Ejercicio 3.** Pide al usuario el saldo de una cuenta. Si el saldo es negativo, imprime `"Cuenta en descubierto"`. Si el saldo es cero, imprime `"Cuenta en cero"`. Si es positivo, no imprimas nada.

# %%
# tu código

# %% [markdown]
# ## FLU-04 · `if` anidados
#
# Podemos poner un `if` dentro de otro cuando una decisión depende de otra decisión previa. La indentación indica el nivel de anidación.
#
# ```
# if condicion_externa:
#     if condicion_interna:
#         # bloque interno True
#     else:
#         # bloque interno False
# else:
#     # bloque externo False
# ```
#
# El `if` interno sólo se evalúa cuando la condición externa dio `True`. Cuando anidamos muchos niveles el código se vuelve difícil de leer: en varios casos se puede reemplazar por una condición combinada con `and`.

# %%
# Ejemplo: ¿puede conducir?
edad = int(input("Edad: "))
licencia = input("¿Tienes licencia? (si/no): ")

if edad >= 18:
    if licencia == "si":
        print("Puedes conducir")
    else:
        print("Debes obtener licencia")
else:
    print("Aún no puedes conducir")
# Out:
# Edad: 10
# ¿Tienes licencia? (si/no): si
# Aún no puedes conducir

# %% [markdown]
# **Ejercicio 4.** Un banco autoriza un préstamo si el cliente tiene sueldo mayor a $500.000 y además no tiene deudas.
#
# Pide al usuario el sueldo (número) y si tiene deudas (`si` / `no`), y muestra en pantalla:
#
# - `"Préstamo aprobado"` si cumple ambas condiciones
# - `"Préstamo rechazado por deudas"` si el sueldo es suficiente pero tiene deudas
# - `"Préstamo rechazado por sueldo insuficiente"` si el sueldo no alcanza
#
# Resuélvelo primero con `if` anidados.

# %%
# tu código

# %% [markdown]
# ## Ejercicio integrador · año bisiesto
#
# Un año es bisiesto si es divisible por 4, excepto los divisibles por 100, salvo que además sean divisibles por 400.
#
# Escribe un programa que pida un año al usuario e imprima `"bisiesto"` o `"no bisiesto"`.
#
# Casos para probar:
#
# | Año | Resultado |
# |---|---|
# | 2000 | bisiesto (divisible por 400) |
# | 1900 | no bisiesto (divisible por 100 pero no por 400) |
# | 2024 | bisiesto (divisible por 4, no por 100) |
# | 2023 | no bisiesto |
#
# Intenta resolverlo primero con `if` anidados y después reescríbelo usando `and` / `or` en una sola condición.

# %%
# tu código

# %%
'''
Valide si no es número entero que escriba un mensaje
y si es número entero que haga una operación

'''

numero = input("Escriba un número entre el 1 y el 2")

if type(numero) != int:

# %% [markdown]
# ---
#
# Para dudas: dlealo@estudiante.uc.cl · Coordinación: iic1103@uc.cl
